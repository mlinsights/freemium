# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore') #ignore warnings
df = pd.read_csv('https://raw.githubusercontent.com/mlinsights/freemium/main/datasets/regression-analysis/real-estate-house-pricing/real_estate_data.csv')
df = df.iloc[:,1:] #retrieve house pricing data
df.head()
# Out:
#    house_age  dist_nStation  num_cStores  dist_nStation.1       lat  \
# 0       32.0       84.87882           10         84.87882  24.98298
# 1       19.5      306.59470            9        306.59470  24.98034
# 2       13.3      561.98450            5        561.98450  24.98746
# 3       13.3      561.98450            5        561.98450  24.98746
# 4        5.0      390.56840            5        390.56840  24.97937
#
#         long  house_p
# 0  121.54024   3221.5
# 1  121.53951   3587.0
# 2  121.54391   4020.5
# 3  121.54391   4658.0
# 4  121.54245   3663.5
